# %%
import pandas as pd

# %%
yr2018_df= pd.read_csv(r"C:\Users\layin\OneDrive\Desktop\weather project csv file\en_climate_daily_MB_502S001_2018_P1D.csv")

# %%
yr2018_df
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2018-01-01  2018
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2018-01-02  2018
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2018-01-03  2018
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2018-01-04  2018
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2018-01-05  2018
# ..             ...           ...            ...        ...         ...   ...
# 360         -97.25         49.92  WINNIPEG A CS    502S001  2018-12-27  2018
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2018-12-28  2018
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2018-12-29  2018
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2018-12-30  2018
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2018-12-31  2018
#
# ...

# %%
yr2019_df= pd.read_csv(r"C:\Users\layin\OneDrive\Desktop\weather project csv file\en_climate_daily_MB_502S001_2019_P1D.csv")
yr2019_df
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2019-01-01  2019
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2019-01-02  2019
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2019-01-03  2019
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2019-01-04  2019
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2019-01-05  2019
# ..             ...           ...            ...        ...         ...   ...
# 360         -97.25         49.92  WINNIPEG A CS    502S001  2019-12-27  2019
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2019-12-28  2019
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2019-12-29  2019
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2019-12-30  2019
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2019-12-31  2019
#
# ...

# %%
yr2020_df= pd.read_csv(r"C:\Users\layin\OneDrive\Desktop\weather project csv file\en_climate_daily_MB_502S001_2020_P1D.csv")
yr2020_df
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2020-01-01  2020
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2020-01-02  2020
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2020-01-03  2020
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2020-01-04  2020
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2020-01-05  2020
# ..             ...           ...            ...        ...         ...   ...
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2020-12-27  2020
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2020-12-28  2020
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2020-12-29  2020
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2020-12-30  2020
# 365         -97.25         49.92  WINNIPEG A CS    502S001  2020-12-31  2020
#
# ...

# %%
yr2021_df= pd.read_csv(r"C:\Users\layin\OneDrive\Desktop\weather project csv file\en_climate_daily_MB_502S001_2021_P1D.csv")
yr2021_df
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2021-01-01  2021
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2021-01-02  2021
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2021-01-03  2021
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2021-01-04  2021
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2021-01-05  2021
# ..             ...           ...            ...        ...         ...   ...
# 360         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-27  2021
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-28  2021
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-29  2021
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-30  2021
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31  2021
#
# ...

# %%
yr2022_df= pd.read_csv(r"C:\Users\layin\OneDrive\Desktop\weather project csv file\en_climate_daily_MB_502S001_2022_P1D.csv")
yr2022_df
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2022-01-01  2022
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2022-01-02  2022
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2022-01-03  2022
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2022-01-04  2022
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2022-01-05  2022
# ..             ...           ...            ...        ...         ...   ...
# 360         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-27  2022
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-28  2022
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-29  2022
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-30  2022
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-31  2022
#
# ...

# %%
# Assuming you have nov2018_df, dec2018_df, jan2019_df, and feb2019_df DataFrames
dataframes = [yr2018_df, yr2019_df,yr2020_df,yr2021_df, yr2022_df]

# Concatenate DataFrames along rows (assuming columns are consistent)
winnipeg_df = pd.concat(dataframes, ignore_index=True)

# Print the concatenated DataFrame
winnipeg_df
# Out:
#       Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0            -97.25         49.92  WINNIPEG A CS    502S001  2018-01-01  2018
# 1            -97.25         49.92  WINNIPEG A CS    502S001  2018-01-02  2018
# 2            -97.25         49.92  WINNIPEG A CS    502S001  2018-01-03  2018
# 3            -97.25         49.92  WINNIPEG A CS    502S001  2018-01-04  2018
# 4            -97.25         49.92  WINNIPEG A CS    502S001  2018-01-05  2018
# ...             ...           ...            ...        ...         ...   ...
# 1821         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-27  2022
# 1822         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-28  2022
# 1823         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-29  2022
# 1824         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-30  2022
# 1825         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-31  2022
#
# ...

# %%
winnipeg_df.dtypes
# Out:
# Longitude (x)                float64
# Latitude (y)                 float64
# Station Name                  object
# Climate ID                    object
# Date/Time                     object
# Year                           int64
# Month                          int64
# Day                            int64
# Data Quality                 float64
# Max Temp (°C)                float64
# Max Temp Flag                 object
# Min Temp (°C)                float64
# Min Temp Flag                 object
# Mean Temp (°C)               float64
# Mean Temp Flag                object
# Heat Deg Days (°C)           float64
# Heat Deg Days Flag            object
# Cool Deg Days (°C)           float64
# Cool Deg Days Flag            object
# Total Rain (mm)              float64
# Total Rain Flag               object
# Total Snow (cm)              float64
# Total Snow Flag               object
# Total Precip (mm)            float64
# Total Precip Flag             object
# ...
