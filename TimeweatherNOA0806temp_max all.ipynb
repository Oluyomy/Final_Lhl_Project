# %%
import pandas as pd
# Libraries to work with dataframe
import numpy as np
# Libraries for datetime
import datetime as dt
# Libraries for EDA
import matplotlib as plt
import seaborn as sns
# Libraries for ML
from sklearn import linear_model, datasets
import statsmodels.api as sm

# %%
Calgary_df= pd.read_csv(r'C:\Users\layin\OneDrive\Desktop\Fina_Lhl_project1\Final_Lhl_Project\weather project csv file\uptodatecalgary.csv', index_col="DATE")

# %%
Calgary_df
# Out:
#                 STATION                             NAME  PRCP  SNWD  TAVG  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5   NaN
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5   NaN
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5   NaN
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5   NaN
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN   NaN
# ...                 ...                              ...   ...   ...   ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.22   NaN  53.0
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  63.0
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA   NaN   NaN  70.0
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  67.0
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  67.0
#
#             TMAX  TMIN  WDFG   WSFG
# DATE
# 2008-12-23   9.0  -5.0   NaN    NaN
# 2008-12-24  24.0   NaN   NaN    NaN
# 2008-12-25  16.0   2.0   NaN    NaN
# 2008-12-26  27.0   NaN   NaN    NaN
# 2008-12-27  37.0   NaN   NaN    NaN
# ...          ...   ...   ...    ...
# 2023-07-28  58.0  49.0   NaN    NaN
# 2023-07-29  77.0  50.0  14.0   69.3
# 2023-07-30  90.0  51.0  33.0  107.4
# 2023-07-31  83.0  52.0  34.0   78.3
# 2023-08-01  80.0  54.0   NaN    NaN
#
# [5260 rows x 9 columns]

# %%
Calgary_df.loc["2018-01-01",:]
# Out:
# STATION                        CA003031094
# NAME       CALGARY INTERNATIONAL CS, AB CA
# PRCP                                   0.0
# SNWD                                   4.3
# TAVG                                   0.0
# TMAX                                  26.0
# TMIN                                 -26.0
# WDFG                                   0.0
# WSFG                                   0.0
# Name: 2018-01-01, dtype: object

# %% [markdown]
# cleaning

# %%
# calculate null percentage

# %%
#find the no of null value in this  columns
Calgary_df.apply(pd.isnull).sum()
# Out:
# STATION       0
# NAME          0
# PRCP         56
# SNWD       3140
# TAVG       2258
# TMAX         29
# TMIN         32
# WDFG       3048
# WSFG       3048
# dtype: int64

# %%
# to calculate the percentage of null divided by the no of rows
null_pct = Calgary_df.apply(pd.isnull).sum() / Calgary_df.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.010646
# SNWD       0.596958
# TAVG       0.429278
# TMAX       0.005513
# TMIN       0.006084
# WDFG       0.579468
# WSFG       0.579468
# dtype: float64

# %%
#select column
Calgary1_df =Calgary_df.iloc[:, [0,1,2,3,5,6]].copy()

# %%
Calgary1_df
# Out:
#                 STATION                             NAME  PRCP  SNWD  TMAX  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5   9.0
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5  24.0
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5  16.0
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   3.5  27.0
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  37.0
# ...                 ...                              ...   ...   ...   ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.22   NaN  58.0
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  77.0
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA   NaN   NaN  90.0
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  83.0
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA  0.00   NaN  80.0
#
#             TMIN
# DATE
# 2008-12-23  -5.0
# 2008-12-24   NaN
# 2008-12-25   2.0
# 2008-12-26   NaN
# 2008-12-27   NaN
# ...          ...
# 2023-07-28  49.0
# 2023-07-29  50.0
# 2023-07-30  51.0
# 2023-07-31  52.0
# 2023-08-01  54.0
#
# [5260 rows x 6 columns]

# %%
Calgary1_df.columns = ["STATION","Name","precip","snow_depth","temp_max", "temp_min"]

# %%
Calgary1_df
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         NaN
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
#
#             temp_max  temp_min
# DATE
# 2008-12-23       9.0      -5.0
# 2008-12-24      24.0       NaN
# 2008-12-25      16.0       2.0
# 2008-12-26      27.0       NaN
# 2008-12-27      37.0       NaN
# ...              ...       ...
# 2023-07-28      58.0      49.0
# 2023-07-29      77.0      50.0
# 2023-07-30      90.0      51.0
# 2023-07-31      83.0      52.0
# 2023-08-01      80.0      54.0
#
# [5260 rows x 6 columns]

# %% [markdown]
# clean up the data and fill null values

# %%
Calgary1_df["snow_depth"]. value_counts()
# Out:
# snow_depth
# 0.0     333
# 0.4     303
# 2.8     185
# 1.2     164
# 0.8     147
# 2.0     139
# 2.4     131
# 1.6     130
# 3.1     124
# 3.5      86
# 3.9      84
# 4.3      64
# 4.7      50
# 5.1      37
# 6.3      35
# 5.5      35
# 5.9      20
# 7.5      14
# 6.7      13
# 7.1       8
# 7.9       5
# 9.4       3
# 8.7       3
# 9.1       2
# 8.3       1
# 9.8       1
# 11.4      1
# 10.2      1
# 10.6      1
# Name: count, dtype: int64

# %% [markdown]
# verify correct data types

# %%
Calgary1_df.dtypes
# Out:
# STATION        object
# Name           object
# precip        float64
# snow_depth    float64
# temp_max      float64
# temp_min      float64
# dtype: object

# %%
Calgary1_df.index
# Out:
# Index(['2008-12-23', '2008-12-24', '2008-12-25', '2008-12-26', '2008-12-27',
#        '2008-12-28', '2008-12-29', '2008-12-30', '2008-12-31', '2009-01-01',
#        ...
#        '2023-07-23', '2023-07-24', '2023-07-25', '2023-07-26', '2023-07-27',
#        '2023-07-28', '2023-07-29', '2023-07-30', '2023-07-31', '2023-08-01'],
#       dtype='object', name='DATE', length=5260)

# %%
# convert out DATE into a datetime
Calgary1_df.index= pd.to_datetime(Calgary1_df.index)

# %%
Calgary1_df.index
# Out:
# DatetimeIndex(['2008-12-23', '2008-12-24', '2008-12-25', '2008-12-26',
#                '2008-12-27', '2008-12-28', '2008-12-29', '2008-12-30',
#                '2008-12-31', '2009-01-01',
#                ...
#                '2023-07-23', '2023-07-24', '2023-07-25', '2023-07-26',
#                '2023-07-27', '2023-07-28', '2023-07-29', '2023-07-30',
#                '2023-07-31', '2023-08-01'],
#               dtype='datetime64[ns]', name='DATE', length=5260, freq=None)

# %%
# we can check  day month ,year
Calgary1_df.index.year
# Out:
# Index([2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2009,
#        ...
#        2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#       dtype='int32', name='DATE', length=5260)

# %%
Calgary1_df.index.day_of_year
# Out:
# Index([358, 359, 360, 361, 362, 363, 364, 365, 366,   1,
#        ...
#        204, 205, 206, 207, 208, 209, 210, 211, 212, 213],
#       dtype='int32', name='DATE', length=5260)

# %%
Calgary1_df.index.month
# Out:
# Index([12, 12, 12, 12, 12, 12, 12, 12, 12,  1,
#        ...
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  8],
#       dtype='int32', name='DATE', length=5260)

# %%
#checking for gaps
Calgary1_df.index.year.value_counts().sort_index()
# Out:
# DATE
# 2008      9
# 2009    363
# 2010    362
# 2011    362
# 2012    364
# 2013    329
# 2014    362
# 2015    363
# 2016    358
# 2017    360
# 2018    360
# 2019    363
# 2020    364
# 2021    363
# 2022    365
# 2023    213
# Name: count, dtype: int64

# %% [markdown]
# Replace null value .

# %%
# select where row is null for min
Calgary1_df[pd.isnull(Calgary1_df["temp_min"])]
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2008-12-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.06         3.9
# 2008-12-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.01         4.3
# 2008-12-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.03         6.7
# 2008-12-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.05         NaN
# 2009-01-02  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2009-01-03  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-05  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-06  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-07  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-08  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.02         2.8
# 2009-01-09  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         2.8
# 2013-07-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2013-08-13  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2013-09-05  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2014-03-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.6
# 2014-12-10  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         3.9
# 2016-08-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2018-10-11  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         2.4
# 2019-03-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.4
# 2019-10-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-10-20  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-10-21  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.4
# 2019-11-13  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.2
# 2019-11-15  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-11-20  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         6.7
# 2020-11-03  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2022-11-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.2
#
#             temp_max  temp_min
# DATE
# 2008-12-24      24.0       NaN
# 2008-12-26      27.0       NaN
# 2008-12-27      37.0       NaN
# 2008-12-28      20.0       NaN
# 2008-12-29      17.0       NaN
# 2008-12-30       NaN       NaN
# 2008-12-31       NaN       NaN
# 2009-01-01       NaN       NaN
# 2009-01-02       NaN       NaN
# 2009-01-03       NaN       NaN
# 2009-01-04       NaN       NaN
# 2009-01-05       NaN       NaN
# 2009-01-06       NaN       NaN
# 2009-01-07       NaN       NaN
# 2009-01-08       NaN       NaN
# 2009-01-09      36.0       NaN
# 2013-07-26      73.0       NaN
# 2013-08-13      76.0       NaN
# 2013-09-05      83.0       NaN
# 2014-03-19       NaN       NaN
# 2014-12-10       NaN       NaN
# 2016-08-04       NaN       NaN
# 2018-10-11       NaN       NaN
# 2019-03-19       NaN       NaN
# 2019-10-19       NaN       NaN
# 2019-10-20       NaN       NaN
# 2019-10-21       NaN       NaN
# 2019-11-13       NaN       NaN
# 2019-11-15       NaN       NaN
# 2019-11-20       NaN       NaN
# 2020-11-03       NaN       NaN
# 2022-11-04       NaN       NaN

# %%
# select where row is null for max
Calgary1_df[pd.isnull(Calgary1_df["temp_max"])]
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.03         6.7
# 2008-12-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.05         NaN
# 2009-01-02  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2009-01-03  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-05  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.1
# 2009-01-06  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-07  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         2.8
# 2009-01-08  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.02         2.8
# 2014-03-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.6
# 2014-12-10  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         3.9
# 2015-12-21  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.2
# 2016-05-05  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2016-07-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2016-08-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2016-09-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2016-10-13  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2017-09-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2018-10-11  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         2.4
# 2019-03-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.4
# 2019-10-19  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-10-20  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-10-21  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.4
# 2019-11-13  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.2
# 2019-11-15  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2019-11-20  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         6.7
# 2020-11-03  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         0.0
# 2022-11-04  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         1.2
#
#             temp_max  temp_min
# DATE
# 2008-12-30       NaN       NaN
# 2008-12-31       NaN       NaN
# 2009-01-01       NaN       NaN
# 2009-01-02       NaN       NaN
# 2009-01-03       NaN       NaN
# 2009-01-04       NaN       NaN
# 2009-01-05       NaN       NaN
# 2009-01-06       NaN       NaN
# 2009-01-07       NaN       NaN
# 2009-01-08       NaN       NaN
# 2014-03-19       NaN       NaN
# 2014-12-10       NaN       NaN
# 2015-12-21       NaN      16.0
# 2016-05-05       NaN      52.0
# 2016-07-26       NaN      53.0
# 2016-08-04       NaN       NaN
# 2016-09-29       NaN      36.0
# 2016-10-13       NaN      22.0
# 2017-09-26       NaN      47.0
# 2018-10-11       NaN       NaN
# 2019-03-19       NaN       NaN
# 2019-10-19       NaN       NaN
# 2019-10-20       NaN       NaN
# 2019-10-21       NaN       NaN
# 2019-11-13       NaN       NaN
# 2019-11-15       NaN       NaN
# 2019-11-20       NaN       NaN
# 2020-11-03       NaN       NaN
# 2022-11-04       NaN       NaN

# %%
# select where row is null for snow_depth
Calgary1_df[pd.isnull(Calgary1_df["snow_depth"])]
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-01-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.05         NaN
# 2009-01-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-04-07  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-04-17  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         NaN
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
#
#             temp_max  temp_min
# DATE
# 2008-12-27      37.0       NaN
# 2009-01-01       NaN       NaN
# 2009-01-31      44.0      15.0
# 2009-04-07      54.0      28.0
# 2009-04-17      60.0      26.0
# ...              ...       ...
# 2023-07-28      58.0      49.0
# 2023-07-29      77.0      50.0
# 2023-07-30      90.0      51.0
# 2023-07-31      83.0      52.0
# 2023-08-01      80.0      54.0
#
# [3140 rows x 6 columns]

# %% [markdown]
# replace null values in snowdepth with 0

# %%
Calgary1_df
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         NaN
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
#
#             temp_max  temp_min
# DATE
# 2008-12-23       9.0      -5.0
# 2008-12-24      24.0       NaN
# 2008-12-25      16.0       2.0
# 2008-12-26      27.0       NaN
# 2008-12-27      37.0       NaN
# ...              ...       ...
# 2023-07-28      58.0      49.0
# 2023-07-29      77.0      50.0
# 2023-07-30      90.0      51.0
# 2023-07-31      83.0      52.0
# 2023-08-01      80.0      54.0
#
# [5260 rows x 6 columns]

# %%
# select where row is null for snow_depth
Calgary1_df[pd.isnull(Calgary1_df["snow_depth"])]
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-01-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.05         NaN
# 2009-01-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-04-07  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2009-04-17  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         NaN
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA     NaN         NaN
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         NaN
#
#             temp_max  temp_min
# DATE
# 2008-12-27      37.0       NaN
# 2009-01-01       NaN       NaN
# 2009-01-31      44.0      15.0
# 2009-04-07      54.0      28.0
# 2009-04-17      60.0      26.0
# ...              ...       ...
# 2023-07-28      58.0      49.0
# 2023-07-29      77.0      50.0
# 2023-07-30      90.0      51.0
# 2023-07-31      83.0      52.0
# 2023-08-01      80.0      54.0
#
# [3140 rows x 6 columns]

# %%
Calgary1_df[["precip"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1_df["snow_depth"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1_df['snow_depth'].fillna(0, inplace=True)

# %% [markdown]
# more than 6inches of snow  are present  with the highest more than 10inches in 2018. 2020 has 6inches

# %%
#tomorrows temp_max

# %%
#fill all  values with the previous ones in temp_max and temp_min and others. this is called forward fill
Calgary1c_df = Calgary1_df.fillna(method="ffill")

# %%
Calgary1c_df.head()
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA     0.0         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA     0.0         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA     0.0         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA     0.0         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA     0.0         0.0
#
#             temp_max  temp_min
# DATE
# 2008-12-23       9.0      -5.0
# 2008-12-24      24.0      -5.0
# 2008-12-25      16.0       2.0
# 2008-12-26      27.0       2.0
# 2008-12-27      37.0       2.0

# %%
Calgary1c_df.loc["2009-01-31",:]
# Out:
# STATION                           CA003031094
# Name          CALGARY INTERNATIONAL CS, AB CA
# precip                                    0.0
# snow_depth                                0.0
# temp_max                                 44.0
# temp_min                                 15.0
# Name: 2009-01-31 00:00:00, dtype: object

# %%
Calgary1_df["snow_depth"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
#tomorrows temp_max

# %% [markdown]
# analysing weather data

# %%
Calgary1c_df[["precip","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1c_df[["precip","temp_max"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1c_df[["snow_depth","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1c_df[["temp_max","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# plot of snow_depth after filling
Calgary1c_df[["snow_depth"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1c_df[["temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import pandas as pd
features = ["precip","snow_depth","temp_max", "temp_min"]

# Grouping by 'Year' and 'Month' and calculating the mean values for weather features
yearmonth_weather_avg = Calgary1c_df.groupby([Calgary1_df.index.year,Calgary1_df.index.month])[features].mean()

# Displaying the calculated averages
yearmonth_weather_avg
# Out:
#              precip  snow_depth   temp_max   temp_min
# DATE DATE
# 2008 12    0.011111    3.522222  20.444444   0.444444
# 2009 1     0.004194    1.716129  31.064516   9.161290
#      2     0.005357    1.542857  28.928571   9.428571
#      3     0.039355    1.706452  34.161290  13.096774
#      4     0.005000    0.480000  49.166667  26.033333
# ...             ...         ...        ...        ...
# 2023 4     0.008000    0.133333  52.266667  27.300000
#      5     0.031613    0.000000  71.677419  43.612903
#      6     0.082000    0.000000  72.833333  47.300000
#      7     0.052581    0.000000  77.064516  51.064516
#      8     0.000000    0.000000  80.000000  54.000000
#
# [177 rows x 4 columns]

# %%
# checking total weather condition per year
Calgary1c_df.groupby(Calgary1c_df.index.year).sum()
# Out:
#                                                 STATION  \
# DATE
# 2008  CA003031094CA003031094CA003031094CA003031094CA...
# 2009  CA003031094CA003031094CA003031094CA003031094CA...
# 2010  CA003031094CA003031094CA003031094CA003031094CA...
# 2011  CA003031094CA003031094CA003031094CA003031094CA...
# 2012  CA003031094CA003031094CA003031094CA003031094CA...
# 2013  CA003031094CA003031094CA003031094CA003031094CA...
# 2014  CA003031094CA003031094CA003031094CA003031094CA...
# 2015  CA003031094CA003031094CA003031094CA003031094CA...
# 2016  CA003031094CA003031094CA003031094CA003031094CA...
# 2017  CA003031094CA003031094CA003031094CA003031094CA...
# 2018  CA003031094CA003031094CA003031094CA003031094CA...
# 2019  CA003031094CA003031094CA003031094CA003031094CA...
# 2020  CA003031094CA003031094CA003031094CA003031094CA...
# 2021  CA003031094CA003031094CA003031094CA003031094CA...
# 2022  CA003031094CA003031094CA003031094CA003031094CA...
# 2023  CA003031094CA003031094CA003031094CA003031094CA...
#
#                                                    Name  precip  snow_depth  \
# DATE
# 2008  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...    0.10        31.7
# 2009  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...    9.45       240.5
# 2010  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   13.02       226.1
# 2011  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   14.95       343.0
# 2012  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   14.49       171.7
# 2013  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   16.09       730.8
# 2014  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   14.51       478.4
# 2015  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   25.90       121.7
# 2016  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   16.34       168.4
# 2017  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   13.43       255.2
# 2018  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   13.24       393.4
# 2019  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   16.88       257.5
# 2020  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   18.83       245.6
# 2021  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   10.89       213.1
# 2022  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...   12.98       250.3
# 2023  CALGARY INTERNATIONAL CS, AB CACALGARY INTERNA...    6.48       280.7
#
#       temp_max  temp_min
# DATE
# 2008     184.0       4.0
# 2009   18212.0    9808.0
# 2010   18299.0   10513.0
# 2011   17969.0   10437.0
# 2012   18623.0   10967.0
# 2013   16326.0    9300.0
# 2014   18147.0   10741.0
# 2015   19518.0   11657.0
# 2016   18921.0   11047.0
# 2017   18771.0   10453.0
# 2018   18071.0    9790.0
# 2019   17630.0    9850.0
# 2020   18533.0   10480.0
# 2021   19008.0   10441.0
# 2022   18952.0   10608.0
# 2023   11328.0    6274.0

# %%
#temp_max per year
Calgary1c_df.groupby(Calgary1c_df.index.year).sum()["temp_max"]
# Out:
# DATE
# 2008      184.0
# 2009    18212.0
# 2010    18299.0
# 2011    17969.0
# 2012    18623.0
# 2013    16326.0
# 2014    18147.0
# 2015    19518.0
# 2016    18921.0
# 2017    18771.0
# 2018    18071.0
# 2019    17630.0
# 2020    18533.0
# 2021    19008.0
# 2022    18952.0
# 2023    11328.0
# Name: temp_max, dtype: float64

# %%
#snow-depth per year
Calgary1c_df.groupby(Calgary1c_df.index.year).sum()["temp_max"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
Calgary1c_df.groupby(Calgary1c_df.index.year).sum()[["precip", "snow_depth", "temp_min", "temp_max"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
#prep per year
Calgary1c_df.groupby(Calgary1c_df.index.year).sum()["temp_max"]
# Out:
# DATE
# 2008      184.0
# 2009    18212.0
# 2010    18299.0
# 2011    17969.0
# 2012    18623.0
# 2013    16326.0
# 2014    18147.0
# 2015    19518.0
# 2016    18921.0
# 2017    18771.0
# 2018    18071.0
# 2019    17630.0
# 2020    18533.0
# 2021    19008.0
# 2022    18952.0
# 2023    11328.0
# Name: temp_max, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt_fig = plt.figure(figsize=(10, 6))
sns.scatterplot(data=Calgary1c_df, x='precip', y='temp_min', hue='temp_max')

plt.show()

# %%
Calgary1c_df
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         0.0
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
#
#             temp_max  temp_min
# DATE
# 2008-12-23       9.0      -5.0
# 2008-12-24      24.0      -5.0
# 2008-12-25      16.0       2.0
# 2008-12-26      27.0       2.0
# 2008-12-27      37.0       2.0
# ...              ...       ...
# 2023-07-28      58.0      49.0
# 2023-07-29      77.0      50.0
# 2023-07-30      90.0      51.0
# 2023-07-31      83.0      52.0
# 2023-08-01      80.0      54.0
#
# [5260 rows x 6 columns]

# %% [markdown]
# ===================================================================================================

# %%
predictors_columns = ["precip", "snow_depth", "temp_max", "temp_min"]
Calgary1c_predictors_df = Calgary1c_df[predictors_columns]

# %%
Calgary1c_predictors_df
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 2008-12-23    0.00         3.5       9.0      -5.0
# 2008-12-24    0.00         3.5      24.0      -5.0
# 2008-12-25    0.00         3.5      16.0       2.0
# 2008-12-26    0.00         3.5      27.0       2.0
# 2008-12-27    0.00         0.0      37.0       2.0
# ...            ...         ...       ...       ...
# 2023-07-28    0.22         0.0      58.0      49.0
# 2023-07-29    0.00         0.0      77.0      50.0
# 2023-07-30    0.00         0.0      90.0      51.0
# 2023-07-31    0.00         0.0      83.0      52.0
# 2023-08-01    0.00         0.0      80.0      54.0
#
# [5260 rows x 4 columns]

# %%
X = Calgary1c_predictors_df.drop(['temp_max'], axis =1)
y = Calgary1c_predictors_df['temp_max']

# %%
X.head()
# Out:
#             precip  snow_depth  temp_min
# DATE
# 2008-12-23     0.0         3.5      -5.0
# 2008-12-24     0.0         3.5      -5.0
# 2008-12-25     0.0         3.5       2.0
# 2008-12-26     0.0         3.5       2.0
# 2008-12-27     0.0         0.0       2.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.scatterplot(x='temp_max', y='temp_min', hue='precip', palette='inferno', data=Calgary1c_predictors_df )

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.scatterplot(x='precip', y='temp_min', hue='snow_depth', palette='inferno', data=Calgary1c_predictors_df )

plt.show()

# %%
#import libraries spliting
from sklearn.model_selection import train_test_split

# %%
#split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((3682, 3), (1578, 3))

# %%
y_train.shape , y_test.shape
# Out:
# ((3682,), (1578,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Linear Regression model
lr_model = LinearRegression()

# Fit the training data
lr_model.fit(X_train, y_train)

# Make predictions
y_pred = lr_model.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("LinearRegression Metrics:")
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# LinearRegression Metrics:
# Mean Squared Error: 67.67912999732378
# Mean Absolute Error: 6.645298951351534
# R-squared: 0.8530703269689108

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a Decision Tree Regression model
dt_model = DecisionTreeRegressor(max_depth=5)

# Fit training data
dt_model.fit(X_train, y_train)

# predictions the testing data
y_pred = dt_model.predict(X_test)
# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("DecisionTreeRegressor Metrics:")
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# DecisionTreeRegressor Metrics:
# Mean Squared Error: 66.18993632554022
# Mean Absolute Error: 6.514771297927346
# R-squared: 0.8563033286236864

# %% [markdown]
# Based on these matrics, the Decision Tree Regression model appears to perform slightly better than the Linear Regression model in terms of both MSE and MAE, while also having a slightly higher R-squared value. This suggests that the Decision Tree Regression model might capture the underlying patterns in this data more effectively. however,it is important to further analyze and potentially improve the models, explore feature engineering, and consider the broader context of this analysis before making a final decision.

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Ridge Regression model
ridge_model = Ridge(alpha=0.1)  

# Fit training data
ridge_model.fit(X_train, y_train)

# Make predictions for the test data
y_pred = ridge_model.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Ridge Regression Metrics:")
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Ridge Regression Metrics:
# Mean Squared Error: 67.67529819650352
# Mean Absolute Error: 6.645300256560981
# R-squared: 0.8530786457112123

# %% [markdown]
# I chose Ridge regression because ridge regression model penalizes coefficients to account for multi-collinearity.

# %% [markdown]
# ensemble

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create a Random Forest Regression model
rf_model = RandomForestRegressor(n_estimators=100, max_depth=10)
# Fit the training data
rf_model.fit(X_train, y_train)
# Make predictions on the testing data
y_pred = rf_model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred)
mae_rf = mean_absolute_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)

# Print the evaluation metrics for RandomForestRegressor
print("RandomForestRegressor Metrics:")
print("Mean Squared Error:", mse_rf)
print("Mean Absolute Error:", mae_rf)
print("R-squared:", r2_rf)
# Out:
# RandomForestRegressor Metrics:
# Mean Squared Error: 68.29979903687347
# Mean Absolute Error: 6.564788360696153
# R-squared: 0.8517228702411845

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Create a Gradient Boosting Regression model
gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)
# Fit the model to the training data
gb_model.fit(X_train, y_train)
# Make predictions on the testing data
y_pred = gb_model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred)
mae_rf = mean_absolute_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)

# Print the evaluation metrics for RandomForestRegressor
print("GradientBoostingRegressorMetrics:")
print("Mean Squared Error:", mse_rf)
print("Mean Absolute Error:", mae_rf)
print("R-squared:", r2_rf)
# Out:
# GradientBoostingRegressorMetrics:
# Mean Squared Error: 61.597367904142466
# Mean Absolute Error: 6.30698274491797
# R-squared: 0.8662736780734439

# %% [markdown]
# Comparing the metrics, the GradientBoostingRegressor outperforms the RandomForestRegressor in terms of all three metrics: lower MSE, slightly lower MAE, and higher R-squared. This indicates that the GradientBoostingRegressor is better capturing the patterns in the data and providing more accurate predictions,but it's important to  perform additional model tuning or exploration to ensure the best possible fit .

# %% [markdown]
# ===================================================================================================================================

# %% [markdown]
# exploring  more feature engineering by creating more predictors, and considering the broader context of this analysis before making a final decision. lets start with predicting tomorrows snow_depth.

# %% [markdown]
# target variable = snow_depth while others are the predictors: predict a target value based on the previous values of a feature (in this case, "snow_depth").

# %%
 #target is snow_depth
Calgary1c_df["target"] = Calgary1c_df. shift(-1)["temp_min"]# replace value one that was originally the row bellow. eg, assign tomorrows value to today.

# %%
Calgary1c_df
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         0.0
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
#
#             temp_max  temp_min  target
# DATE
# 2008-12-23       9.0      -5.0    -5.0
# 2008-12-24      24.0      -5.0     2.0
# 2008-12-25      16.0       2.0     2.0
# 2008-12-26      27.0       2.0     2.0
# 2008-12-27      37.0       2.0     2.0
# ...              ...       ...     ...
# 2023-07-28      58.0      49.0    50.0
# 2023-07-29      77.0      50.0    51.0
# 2023-07-30      90.0      51.0    52.0
# 2023-07-31      83.0      52.0    54.0
# 2023-08-01      80.0      54.0     NaN
#
# [5260 rows x 7 columns]

# %% [markdown]
#  the above predicted tomorrows snow_depth from today eg the target (0.00) of 2008-12-24 is tomorrows  (0). it helps predict tomorrows precip

# %% [markdown]
# Notice the last target for 2023-08-1 has NAN this is because the last data i downloaded was on that day,we will can fill the data with the previous value. ((   'r' in Calgary1cf_df mean fill))

# %%
Calgary1cf_df= Calgary1c_df.ffill()

# %%
Calgary1cf_df
# Out:
#                 STATION                             Name  precip  snow_depth  \
# DATE
# 2008-12-23  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-24  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-25  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-26  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         3.5
# 2008-12-27  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# ...                 ...                              ...     ...         ...
# 2023-07-28  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.22         0.0
# 2023-07-29  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-30  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-07-31  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
# 2023-08-01  CA003031094  CALGARY INTERNATIONAL CS, AB CA    0.00         0.0
#
#             temp_max  temp_min  target
# DATE
# 2008-12-23       9.0      -5.0    -5.0
# 2008-12-24      24.0      -5.0     2.0
# 2008-12-25      16.0       2.0     2.0
# 2008-12-26      27.0       2.0     2.0
# 2008-12-27      37.0       2.0     2.0
# ...              ...       ...     ...
# 2023-07-28      58.0      49.0    50.0
# 2023-07-29      77.0      50.0    51.0
# 2023-07-30      90.0      51.0    52.0
# 2023-07-31      83.0      52.0    54.0
# 2023-08-01      80.0      54.0    54.0
#
# [5260 rows x 7 columns]

# %%
#snow-depth per year
#Calgary1cf_df.groupby(Calgary1cf_df.index.year).sum()['snow_depth','target'].plot()

# %%
Calgary1cfs_df= Calgary1cf_df[['precip','snow_depth','temp_max','temp_min','target']]

# %%
Calgary1cfs_df
# Out:
#             precip  snow_depth  temp_max  temp_min  target
# DATE
# 2008-12-23    0.00         3.5       9.0      -5.0    -5.0
# 2008-12-24    0.00         3.5      24.0      -5.0     2.0
# 2008-12-25    0.00         3.5      16.0       2.0     2.0
# 2008-12-26    0.00         3.5      27.0       2.0     2.0
# 2008-12-27    0.00         0.0      37.0       2.0     2.0
# ...            ...         ...       ...       ...     ...
# 2023-07-28    0.22         0.0      58.0      49.0    50.0
# 2023-07-29    0.00         0.0      77.0      50.0    51.0
# 2023-07-30    0.00         0.0      90.0      51.0    52.0
# 2023-07-31    0.00         0.0      83.0      52.0    54.0
# 2023-08-01    0.00         0.0      80.0      54.0    54.0
#
# [5260 rows x 5 columns]

# %%
corr = Calgary1cfs_df.corr()
target_corr = corr['temp_max'].drop('temp_max')

target_corr_sorted = target_corr.sort_values(ascending=True)

sns.set(font_scale=0.8)
sns.set_style("white")
sns.set_palette("PuBuGn_d")
sns.heatmap(target_corr_sorted.to_frame(), cmap="coolwarm", annot=True, fmt='.2f')
plt.title('Correlation with temp_max')
plt.show()

# %%
#Compute the correlation matrix
corr= Calgary1cfs_df.corr()
corr
# Out:
#               precip  snow_depth  temp_max  temp_min    target
# precip      1.000000   -0.072822  0.040950  0.155116  0.121809
# snow_depth -0.072822    1.000000 -0.564854 -0.591325 -0.563553
# temp_max    0.040950   -0.564854  1.000000  0.918778  0.920757
# temp_min    0.155116   -0.591325  0.918778  1.000000  0.926194
# target      0.121809   -0.563553  0.920757  0.926194  1.000000

# %% [markdown]
# explain correllation.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix


# Plot the heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# Tuning an

# %% [markdown]
# Application of machine learning.
# ridge regression model penalizes coefficients to account for multi-collinearity.

# %% [markdown]
# use regression model because it reduces overfitting

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create a Ridge Regression model
ridge_model = Ridge(alpha=0.1)  # You can adjust the alpha (regularization strength) default value

# %%
# select columns in this list except the target. ~ meaning negation.
predictors = Calgary1cfs_df.columns[~Calgary1cfs_df.columns.isin(["target"])] 
predictors
# Out:
# Index(['precip', 'snow_depth', 'temp_max', 'temp_min'], dtype='object')

# %% [markdown]
# since it is a time series data, we will use time series cross validation or back testing to account for the time series nature of the data.. we have to be careful not to use today's  value to predict yesterday.

# %%
# the function  take in the data, model, predictors, start parameter  of 365 days before we start predictions and this is for a period of 30 days we create a set of predictions and move on to the next 30 days.. this can be adjusted.
def backtest(Calgary1cfs_df,ridge_model,predictors,start=365,step=30):
    all_predictions=[]

    for i in range(start, Calgary1cfs_df.shape[0], step):
        train = Calgary1cfs_df.iloc[:i,:]
        test = Calgary1cfs_df.iloc[i:i+step,:]

        ridge_model.fit(train[predictors], train["target"])

        preds =ridge_model.predict(test[predictors])

        preds  = pd.Series(preds, index=test.index)

        combined= pd.concat([test["target"],preds], axis=1)
        combined.columns= ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        all_predictions.append(combined)
        return pd.concat(all_predictions)

# %%
predictions = backtest(Calgary1cfs_df, ridge_model, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 2009-12-25     7.0    3.923992   3.076008
# 2009-12-26    11.0   11.514721   0.514721
# 2009-12-27     9.0   11.971272   2.971272
# 2009-12-28     1.0    8.377436   7.377436
# 2009-12-29    -1.0    5.179610   6.179610
# 2009-12-30   -12.0   -2.791646   9.208354
# 2009-12-31   -10.0  -11.951272   1.951272
# 2010-01-01     4.0   -4.242322   8.242322
# 2010-01-02     3.0    4.714538   1.714538
# 2010-01-03     8.0    3.222902   4.777098
# 2010-01-04    -1.0    5.054106   6.054106
# 2010-01-05   -13.0   -3.265106   9.734894
# 2010-01-06   -12.0   -9.258817   2.741183
# 2010-01-07    14.0   -1.942117  15.942117
# 2010-01-08    19.0   17.557778   1.442222
# 2010-01-09    31.0   19.890016  11.109984
# 2010-01-10    29.0   27.647294   1.352706
# 2010-01-11    33.0   27.820313   5.179687
# 2010-01-12    29.0   28.050351   0.949649
# 2010-01-13    25.0   25.466613   0.466613
# 2010-01-14    22.0   25.010062   3.010062
# 2010-01-15    22.0   23.499420   1.499420
# 2010-01-16    12.0   21.598748   9.598748
# 2010-01-17    21.0   16.899784   4.100216
# 2010-01-18    17.0   23.263403   6.263403
# 2010-01-19    19.0   16.947299   2.052701
# 2010-01-20    17.0   18.221923   1.221923
# 2010-01-21    15.0   11.314260   3.685740
# 2010-01-22    16.0    8.976043   7.023957
# 2010-01-23    11.0    9.020034   1.979966

# %% [markdown]
# The diff show the  how accurate our prediction is we will immport mean_absolute_error

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.714064376297606

# %%
predictions["diff"].mean()
# Out:
# 4.714064376297606

# %% [markdown]
# In summary, your calculated MAE value of 0.0142 suggests that, on average, the absolute difference between the predicted and actual values is approximately 0.0142 units. Lower MAE values indicate better model performance in terms of accuracy and closeness of predictions to the actual values.

# %% [markdown]
# on average, we are 8.8 degrees off in our prediction.

# %%
r2_ridge = r2_score(predictions["actual"], predictions["prediction"])
r2_ridge
# Out:
# 0.7816198852454094

# %%
#combined.plot()

# %%
rmse_ridge = mean_squared_error(predictions["actual"], predictions["prediction"], squared=False)
rmse_ridge
# Out:
# 5.982967309979615

# %%
ridge_model.coef_
# Out:
# array([ 7.02811018, -0.48006381,  0.41853947,  0.42804252])

# %% [markdown]
# These coefficients indicate the direction and magnitude of the relationship between each predictor and the target variable
# For the 'precip' predictor,Coefficient is 0.0912466 and this is is associated with an approximate increase of 0.15149422 units in the predicted target variable (given that all other predictors are held constant). This positive coefficient implies that higher precipitation is generally associated with a higher predicted target value.
# For the 'snow_depth' predictor, the Coefficient is 0.00345681 and A one-unit increase in the snow_depth feature corresponds to an estimated increase of 0.65577987 units in the predicted target variable. This coefficient is also positive, indicating that higher snow depth is associated with a higher predicted target value.
# For the 'temp_max' predictor, the Coefficient is -0.00020038, and ssuggests that a one-unit increase in the temp_max feature is associated with a decrease of approximately 0.00675996 units in the predicted target variable. A negative coefficient implies that higher maximum temperatures are associated with lower predicted target values.
# For the 'temp_min' predictor, 0.00115877 a one-unit increase in the temp_min feature is associated with a decrease of about -0.00709719 units in the predicted target variable. This is also a negative coefficient, indicating that higher minimum temperatures are associated with lower predicted target values.

# %% [markdown]
#  MAE value of0.0142289260131048386 is better than a MAE value of  0.06441458006177278. In other words, the model with the MAE of 0.014228926013104838 has a smaller average absolute difference between predicted and actual values, which suggests that it is making more accurate predictions compared to the model with the higher MAE

# %% [markdown]
# ===========================================================================================================================
# ===========================================================================================================================

# %% [markdown]
# how to improve our accuracy. calculate the average temperature and precipitation in the past few days, 3,14 days and looking how the current day compare to those days.

# %% [markdown]
# d

# %%
def pct_diff(old, new):
    return (new - old) / old  # return new minus old divided by old.

def compute_rolling(Calgary1cfs_df, horizon, col):
    label = f"rolling_{horizon}_{col}"  # to create a label.... used to create a dynamic string
    Calgary1cfs_df[label] = Calgary1cfs_df[col].rolling(horizon).mean()  # note that rolling mean takes the values from previous dates to calculate over the horizon
    Calgary1cfs_df[f"{label}_pct"] = pct_diff(Calgary1cfs_df[label], Calgary1cfs_df[col])  # to find percentage difference between the current day and the rolling

rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["precip", "snow_depth", "temp_max", "temp_min"]:
        compute_rolling(Calgary1cfs_df, horizon, col)
        
Calgary1cfs_df
# Out:
# C:\Users\layin\AppData\Local\Temp\ipykernel_25796\2205066882.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Calgary1cfs_df[label] = Calgary1cfs_df[col].rolling(horizon).mean()  # note that rolling mean takes the values from previous dates to calculate over the horizon
#             precip  snow_depth  temp_max  temp_min  target  rolling_3_precip  \
# DATE
# 2008-12-23    0.00         3.5       9.0      -5.0    -5.0               NaN
# 2008-12-24    0.00         3.5      24.0      -5.0     2.0               NaN
# 2008-12-25    0.00         3.5      16.0       2.0     2.0          0.000000
# 2008-12-26    0.00         3.5      27.0       2.0     2.0          0.000000
# 2008-12-27    0.00         0.0      37.0       2.0     2.0          0.000000
# ...            ...         ...       ...       ...     ...               ...
# 2023-07-28    0.22         0.0      58.0      49.0    50.0          0.106667
# 2023-07-29    0.00         0.0      77.0      50.0    51.0          0.106667
# 2023-07-30    0.00         0.0      90.0      51.0    52.0          0.073333
# 2023-07-31    0.00         0.0      83.0      52.0    54.0          0.000000
# 2023-08-01    0.00         0.0      80.0      54.0    54.0          0.000000
#
#             rolling_3_precip_pct  rolling_3_snow_depth  \
# DATE
# 2008-12-23                   NaN                   NaN
# 2008-12-24                   NaN                   NaN
# 2008-12-25                   NaN              3.500000
# 2008-12-26                   NaN              3.500000
# 2008-12-27                   NaN              2.333333
# ...                          ...                   ...
# 2023-07-28                1.0625              0.000000
# 2023-07-29               -1.0000              0.000000
# 2023-07-30               -1.0000              0.000000
# 2023-07-31                   NaN              0.000000
# 2023-08-01                   NaN              0.000000
#
#             rolling_3_snow_depth_pct  rolling_3_temp_max  ...  \
# DATE                                                      ...
# 2008-12-23                       NaN                 NaN  ...
# 2008-12-24                       NaN                 NaN  ...
# 2008-12-25                       0.0           16.333333  ...
# 2008-12-26                       0.0           22.333333  ...
# 2008-12-27                      -1.0           26.666667  ...
# ...                              ...                 ...  ...
# 2023-07-28                       NaN           66.000000  ...
# 2023-07-29                       NaN           66.666667  ...
# 2023-07-30                       NaN           75.000000  ...
# 2023-07-31                       NaN           83.333333  ...
# 2023-08-01                       NaN           84.333333  ...
#
#             rolling_3_temp_min  rolling_3_temp_min_pct  rolling_14_precip  \
# DATE
# 2008-12-23                 NaN                     NaN                NaN
# 2008-12-24                 NaN                     NaN                NaN
# 2008-12-25           -2.666667               -1.750000                NaN
# 2008-12-26           -0.333333               -7.000000                NaN
# 2008-12-27            2.000000                0.000000                NaN
# ...                        ...                     ...                ...
# 2023-07-28           48.000000                0.020833           0.048571
# 2023-07-29           48.666667                0.027397           0.045714
# 2023-07-30           50.000000                0.020000           0.045714
# 2023-07-31           51.000000                0.019608           0.025714
# 2023-08-01           52.333333                0.031847           0.025714
#
#             rolling_14_precip_pct  rolling_14_snow_depth  \
# DATE
# 2008-12-23                    NaN                    NaN
# 2008-12-24                    NaN                    NaN
# 2008-12-25                    NaN                    NaN
# 2008-12-26                    NaN                    NaN
# 2008-12-27                    NaN                    NaN
# ...                           ...                    ...
# 2023-07-28               3.529412                    0.0
# 2023-07-29              -1.000000                    0.0
# 2023-07-30              -1.000000                    0.0
# 2023-07-31              -1.000000                    0.0
# 2023-08-01              -1.000000                    0.0
#
#             rolling_14_snow_depth_pct  rolling_14_temp_max  \
# DATE
# 2008-12-23                        NaN                  NaN
# 2008-12-24                        NaN                  NaN
# 2008-12-25                        NaN                  NaN
# 2008-12-26                        NaN                  NaN
# 2008-12-27                        NaN                  NaN
# ...                               ...                  ...
# 2023-07-28                        NaN            77.857143
# 2023-07-29                        NaN            77.785714
# 2023-07-30                        NaN            78.428571
# 2023-07-31                        NaN            79.285714
# 2023-08-01                        NaN            79.785714
#
#             rolling_14_temp_max_pct  rolling_14_temp_min  \
# DATE
# 2008-12-23                      NaN                  NaN
# 2008-12-24                      NaN                  NaN
# 2008-12-25                      NaN                  NaN
# 2008-12-26                      NaN                  NaN
# 2008-12-27                      NaN                  NaN
# ...                             ...                  ...
# 2023-07-28                -0.255046            51.928571
# 2023-07-29                -0.010101            51.642857
# 2023-07-30                 0.147541            51.428571
# 2023-07-31                 0.046847            51.571429
# 2023-08-01                 0.002686            52.071429
#
#             rolling_14_temp_min_pct
# DATE
# 2008-12-23                      NaN
# 2008-12-24                      NaN
# 2008-12-25                      NaN
# 2008-12-26                      NaN
# 2008-12-27                      NaN
# ...                             ...
# 2023-07-28                -0.056396
# 2023-07-29                -0.031812
# 2023-07-30                -0.008333
# 2023-07-31                 0.008310
# 2023-08-01                 0.037037
#
# [5260 rows x 21 columns]

# %% [markdown]
# cut off the first 14 days with missing valuea because there is no prediction for them.

# %%
Calgary1cfs_df = Calgary1cfs_df.iloc[14:,:]

# %%
Calgary1cfs_df
# Out:
#             precip  snow_depth  temp_max  temp_min  target  rolling_3_precip  \
# DATE
# 2009-01-06    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-07    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-08    0.02         2.8      17.0       2.0     2.0          0.006667
# 2009-01-09    0.02         2.8      36.0       2.0    23.0          0.013333
# 2009-01-10    0.00         2.8      39.0      23.0    18.0          0.013333
# ...            ...         ...       ...       ...     ...               ...
# 2023-07-28    0.22         0.0      58.0      49.0    50.0          0.106667
# 2023-07-29    0.00         0.0      77.0      50.0    51.0          0.106667
# 2023-07-30    0.00         0.0      90.0      51.0    52.0          0.073333
# 2023-07-31    0.00         0.0      83.0      52.0    54.0          0.000000
# 2023-08-01    0.00         0.0      80.0      54.0    54.0          0.000000
#
#             rolling_3_precip_pct  rolling_3_snow_depth  \
# DATE
# 2009-01-06                   NaN                   3.0
# 2009-01-07                   NaN                   2.9
# 2009-01-08                2.0000                   2.8
# 2009-01-09                0.5000                   2.8
# 2009-01-10               -1.0000                   2.8
# ...                          ...                   ...
# 2023-07-28                1.0625                   0.0
# 2023-07-29               -1.0000                   0.0
# 2023-07-30               -1.0000                   0.0
# 2023-07-31                   NaN                   0.0
# 2023-08-01                   NaN                   0.0
#
#             rolling_3_snow_depth_pct  rolling_3_temp_max  ...  \
# DATE                                                      ...
# 2009-01-06                 -0.066667           17.000000  ...
# 2009-01-07                 -0.034483           17.000000  ...
# 2009-01-08                  0.000000           17.000000  ...
# 2009-01-09                  0.000000           23.333333  ...
# 2009-01-10                  0.000000           30.666667  ...
# ...                              ...                 ...  ...
# 2023-07-28                       NaN           66.000000  ...
# 2023-07-29                       NaN           66.666667  ...
# 2023-07-30                       NaN           75.000000  ...
# 2023-07-31                       NaN           83.333333  ...
# 2023-08-01                       NaN           84.333333  ...
#
#             rolling_3_temp_min  rolling_3_temp_min_pct  rolling_14_precip  \
# DATE
# 2009-01-06            2.000000                0.000000           0.010714
# 2009-01-07            2.000000                0.000000           0.010714
# 2009-01-08            2.000000                0.000000           0.012143
# 2009-01-09            2.000000                0.000000           0.013571
# 2009-01-10            9.000000                1.555556           0.013571
# ...                        ...                     ...                ...
# 2023-07-28           48.000000                0.020833           0.048571
# 2023-07-29           48.666667                0.027397           0.045714
# 2023-07-30           50.000000                0.020000           0.045714
# 2023-07-31           51.000000                0.019608           0.025714
# 2023-08-01           52.333333                0.031847           0.025714
#
#             rolling_14_precip_pct  rolling_14_snow_depth  \
# DATE
# 2009-01-06              -1.000000               3.128571
# 2009-01-07              -1.000000               3.078571
# 2009-01-08               0.647059               3.028571
# 2009-01-09               0.473684               2.978571
# 2009-01-10              -1.000000               3.178571
# ...                           ...                    ...
# 2023-07-28               3.529412               0.000000
# 2023-07-29              -1.000000               0.000000
# 2023-07-30              -1.000000               0.000000
# 2023-07-31              -1.000000               0.000000
# 2023-08-01              -1.000000               0.000000
#
#             rolling_14_snow_depth_pct  rolling_14_temp_max  \
# DATE
# 2009-01-06                  -0.105023            19.785714
# 2009-01-07                  -0.090487            19.285714
# 2009-01-08                  -0.075472            19.357143
# 2009-01-09                  -0.059952            20.000000
# 2009-01-10                  -0.119101            20.142857
# ...                               ...                  ...
# 2023-07-28                        NaN            77.857143
# 2023-07-29                        NaN            77.785714
# 2023-07-30                        NaN            78.428571
# 2023-07-31                        NaN            79.285714
# 2023-08-01                        NaN            79.785714
#
#             rolling_14_temp_max_pct  rolling_14_temp_min  \
# DATE
# 2009-01-06                -0.140794             1.500000
# 2009-01-07                -0.118519             2.000000
# 2009-01-08                -0.121771             2.000000
# 2009-01-09                 0.800000             2.000000
# 2009-01-10                 0.936170             3.500000
# ...                             ...                  ...
# 2023-07-28                -0.255046            51.928571
# 2023-07-29                -0.010101            51.642857
# 2023-07-30                 0.147541            51.428571
# 2023-07-31                 0.046847            51.571429
# 2023-08-01                 0.002686            52.071429
#
#             rolling_14_temp_min_pct
# DATE
# 2009-01-06                 0.333333
# 2009-01-07                 0.000000
# 2009-01-08                 0.000000
# 2009-01-09                 0.000000
# 2009-01-10                 5.571429
# ...                             ...
# 2023-07-28                -0.056396
# 2023-07-29                -0.031812
# 2023-07-30                -0.008333
# 2023-07-31                 0.008310
# 2023-08-01                 0.037037
#
# [5246 rows x 21 columns]

# %% [markdown]
# some NAN is still in the percentage columns(pct)  and we have to solve them by filling them with 0 in the next cell

# %%
Calgary1cfs_df =Calgary1cfs_df.fillna(0)

# %% [markdown]
# Add more predictions

# %%
def expand_mean(x):
    return x.expanding(1).mean()

for col in ["precip", "snow_depth", "temp_max", "temp_min"]:
    Calgary1cfs_df[f"month_avg_{col}"] = Calgary1cfs_df.groupby(Calgary1cfs_df.index.month)[col].apply(expand_mean).reset_index(level=0, drop=True)#(drop original index so it aligns with original df when assigning values back)
    Calgary1cfs_df[f"day_avg_{col}"] = Calgary1cfs_df.groupby(Calgary1cfs_df.index.day_of_year)[col].apply(expand_mean).reset_index(level=0, drop=True)

# %%
Calgary1cfs_df
# Out:
#             precip  snow_depth  temp_max  temp_min  target  rolling_3_precip  \
# DATE
# 2009-01-06    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-07    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-08    0.02         2.8      17.0       2.0     2.0          0.006667
# 2009-01-09    0.02         2.8      36.0       2.0    23.0          0.013333
# 2009-01-10    0.00         2.8      39.0      23.0    18.0          0.013333
# ...            ...         ...       ...       ...     ...               ...
# 2023-07-28    0.22         0.0      58.0      49.0    50.0          0.106667
# 2023-07-29    0.00         0.0      77.0      50.0    51.0          0.106667
# 2023-07-30    0.00         0.0      90.0      51.0    52.0          0.073333
# 2023-07-31    0.00         0.0      83.0      52.0    54.0          0.000000
# 2023-08-01    0.00         0.0      80.0      54.0    54.0          0.000000
#
#             rolling_3_precip_pct  rolling_3_snow_depth  \
# DATE
# 2009-01-06                0.0000                   3.0
# 2009-01-07                0.0000                   2.9
# 2009-01-08                2.0000                   2.8
# 2009-01-09                0.5000                   2.8
# 2009-01-10               -1.0000                   2.8
# ...                          ...                   ...
# 2023-07-28                1.0625                   0.0
# 2023-07-29               -1.0000                   0.0
# 2023-07-30               -1.0000                   0.0
# 2023-07-31                0.0000                   0.0
# 2023-08-01                0.0000                   0.0
#
#             rolling_3_snow_depth_pct  rolling_3_temp_max  ...  \
# DATE                                                      ...
# 2009-01-06                 -0.066667           17.000000  ...
# 2009-01-07                 -0.034483           17.000000  ...
# 2009-01-08                  0.000000           17.000000  ...
# 2009-01-09                  0.000000           23.333333  ...
# 2009-01-10                  0.000000           30.666667  ...
# ...                              ...                 ...  ...
# 2023-07-28                  0.000000           66.000000  ...
# 2023-07-29                  0.000000           66.666667  ...
# 2023-07-30                  0.000000           75.000000  ...
# 2023-07-31                  0.000000           83.333333  ...
# 2023-08-01                  0.000000           84.333333  ...
#
#             rolling_14_temp_min  rolling_14_temp_min_pct  month_avg_precip  \
# DATE
# 2009-01-06             1.500000                 0.333333          0.000000
# 2009-01-07             2.000000                 0.000000          0.000000
# 2009-01-08             2.000000                 0.000000          0.006667
# 2009-01-09             2.000000                 0.000000          0.010000
# 2009-01-10             3.500000                 5.571429          0.008000
# ...                         ...                      ...               ...
# 2023-07-28            51.928571                -0.056396          0.074073
# 2023-07-29            51.642857                -0.031812          0.073904
# 2023-07-30            51.428571                -0.008333          0.073736
# 2023-07-31            51.571429                 0.008310          0.073568
# 2023-08-01            52.071429                 0.037037          0.065891
#
#             day_avg_precip  month_avg_snow_depth  day_avg_snow_depth  \
# DATE
# 2009-01-06        0.000000                   2.8                 2.8
# 2009-01-07        0.000000                   2.8                 2.8
# 2009-01-08        0.020000                   2.8                 2.8
# 2009-01-09        0.020000                   2.8                 2.8
# 2009-01-10        0.000000                   2.8                 2.8
# ...                    ...                   ...                 ...
# 2023-07-28        0.019286                   0.0                 0.0
# 2023-07-29        0.022143                   0.0                 0.0
# 2023-07-30        0.022857                   0.0                 0.0
# 2023-07-31        0.000714                   0.0                 0.0
# 2023-08-01        0.060714                   0.0                 0.0
#
#             month_avg_temp_max  day_avg_temp_max  month_avg_temp_min  \
# DATE
# 2009-01-06           17.000000         17.000000            2.000000
# 2009-01-07           17.000000         17.000000            2.000000
# 2009-01-08           17.000000         17.000000            2.000000
# 2009-01-09           21.750000         36.000000            2.000000
# 2009-01-10           25.200000         39.000000            6.200000
# ...                        ...               ...                 ...
# 2023-07-28           74.791762         75.642857           51.160183
# 2023-07-29           74.796804         77.714286           51.157534
# 2023-07-30           74.831435         81.000000           51.157175
# 2023-07-31           74.850000         80.785714           51.159091
# 2023-08-01           74.277910         78.928571           49.572447
#
#             day_avg_temp_min
# DATE
# 2009-01-06          2.000000
# 2009-01-07          2.000000
# 2009-01-08          2.000000
# 2009-01-09          2.000000
# 2009-01-10         23.000000
# ...                      ...
# 2023-07-28         50.714286
# 2023-07-29         51.642857
# 2023-07-30         50.928571
# 2023-07-31         51.928571
# 2023-08-01         54.428571
#
# [5246 rows x 29 columns]

# %%
Calgary1cfs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5246 entries, 2009-01-06 to 2023-08-01
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   precip                     5246 non-null   float64
#  1   snow_depth                 5246 non-null   float64
#  2   temp_max                   5246 non-null   float64
#  3   temp_min                   5246 non-null   float64
#  4   target                     5246 non-null   float64
#  5   rolling_3_precip           5246 non-null   float64
#  6   rolling_3_precip_pct       5246 non-null   float64
#  7   rolling_3_snow_depth       5246 non-null   float64
#  8   rolling_3_snow_depth_pct   5246 non-null   float64
#  9   rolling_3_temp_max         5246 non-null   float64
#  10  rolling_3_temp_max_pct     5246 non-null   float64
#  11  rolling_3_temp_min         5246 non-null   float64
#  12  rolling_3_temp_min_pct     5246 non-null   float64
#  13  rolling_14_precip          5246 non-null   float64
#  14  rolling_14_precip_pct      5246 non-null   float64
#  15  rolling_14_snow_depth      5246 non-null   float64
#  16  rolling_14_snow_depth_pct  5246 non-null   float64
#  17  rolling_14_temp_max        5246 non-null   float64
#  18  rolling_14_temp_max_pct    5246 non-null   float64
#  19  rolling_14_temp_min        5246 non-null   float64
#  20  rolling_14_temp_min_pct    5246 non-null   float64
#  21  month_avg_precip           5246 non-null   float64
#  22  day_avg_precip             5246 non-null   float64
#  23  month_avg_snow_depth       5246 non-null   float64
#  24  day_avg_snow_depth         5246 non-null   float64
#  25  month_avg_temp_max         5246 non-null   float64
#  26  day_avg_temp_max           5246 non-null   float64
#  27  month_avg_temp_min         5246 non-null   float64
#  28  day_avg_temp_min           5246 non-null   float64
# dtypes: float64(29)
# memory usage: 1.2 MB

# %% [markdown]
# Rerun our predictors, we have included some predictors lets see in our index.

# %%
#we can check our predictors now. .~ mean negation.
predictors = Calgary1cfs_df.columns[~Calgary1cfs_df.columns.isin(["target"])] 
predictors
# Out:
# Index(['precip', 'snow_depth', 'temp_max', 'temp_min', 'rolling_3_precip',
#        'rolling_3_precip_pct', 'rolling_3_snow_depth',
#        'rolling_3_snow_depth_pct', 'rolling_3_temp_max',
#        'rolling_3_temp_max_pct', 'rolling_3_temp_min',
#        'rolling_3_temp_min_pct', 'rolling_14_precip', 'rolling_14_precip_pct',
#        'rolling_14_snow_depth', 'rolling_14_snow_depth_pct',
#        'rolling_14_temp_max', 'rolling_14_temp_max_pct', 'rolling_14_temp_min',
#        'rolling_14_temp_min_pct', 'month_avg_precip', 'day_avg_precip',
#        'month_avg_snow_depth', 'day_avg_snow_depth', 'month_avg_temp_max',
#        'day_avg_temp_max', 'month_avg_temp_min', 'day_avg_temp_min'],
#       dtype='object')

# %% [markdown]
# predictors

# %%
 #Check for infinity values in each column
inf_columns =Calgary1cfs_df.columns[Calgary1cfs_df.applymap(np.isinf).any()]


inf_columns
# Out:
# Index(['rolling_3_temp_max_pct', 'rolling_3_temp_min_pct',
#        'rolling_14_temp_min_pct'],
#       dtype='object')

# %% [markdown]
# it needs cleaning because of this infinity in the columns, so it has to be dealth with by fill for our backtesting function to work. this ts done in the next cell.

# %%
Calgary1cfs_df = Calgary1cfs_df.replace([np.inf, -np.inf], np.nan)# code replace all infinite values with NAN using replace and then fill  with previous non nan value along the columns.
Calgary1cfs_df = Calgary1cfs_df.ffill()

# %%
Calgary1cfs_df.apply(pd.isnull).sum()
# Out:
# precip                       0
# snow_depth                   0
# temp_max                     0
# temp_min                     0
# target                       0
# rolling_3_precip             0
# rolling_3_precip_pct         0
# rolling_3_snow_depth         0
# rolling_3_snow_depth_pct     0
# rolling_3_temp_max           0
# rolling_3_temp_max_pct       0
# rolling_3_temp_min           0
# rolling_3_temp_min_pct       0
# rolling_14_precip            0
# rolling_14_precip_pct        0
# rolling_14_snow_depth        0
# rolling_14_snow_depth_pct    0
# rolling_14_temp_max          0
# rolling_14_temp_max_pct      0
# rolling_14_temp_min          0
# rolling_14_temp_min_pct      0
# month_avg_precip             0
# day_avg_precip               0
# month_avg_snow_depth         0
# day_avg_snow_depth           0
# month_avg_temp_max           0
# day_avg_temp_max             0
# month_avg_temp_min           0
# day_avg_temp_min             0
# dtype: int64

# %%
# backtest function to call our predictions
predictions = backtest(Calgary1cfs_df, ridge_model, predictors)

# %%
Calgary1cfs_df
# Out:
#             precip  snow_depth  temp_max  temp_min  target  rolling_3_precip  \
# DATE
# 2009-01-06    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-07    0.00         2.8      17.0       2.0     2.0          0.000000
# 2009-01-08    0.02         2.8      17.0       2.0     2.0          0.006667
# 2009-01-09    0.02         2.8      36.0       2.0    23.0          0.013333
# 2009-01-10    0.00         2.8      39.0      23.0    18.0          0.013333
# ...            ...         ...       ...       ...     ...               ...
# 2023-07-28    0.22         0.0      58.0      49.0    50.0          0.106667
# 2023-07-29    0.00         0.0      77.0      50.0    51.0          0.106667
# 2023-07-30    0.00         0.0      90.0      51.0    52.0          0.073333
# 2023-07-31    0.00         0.0      83.0      52.0    54.0          0.000000
# 2023-08-01    0.00         0.0      80.0      54.0    54.0          0.000000
#
#             rolling_3_precip_pct  rolling_3_snow_depth  \
# DATE
# 2009-01-06                0.0000                   3.0
# 2009-01-07                0.0000                   2.9
# 2009-01-08                2.0000                   2.8
# 2009-01-09                0.5000                   2.8
# 2009-01-10               -1.0000                   2.8
# ...                          ...                   ...
# 2023-07-28                1.0625                   0.0
# 2023-07-29               -1.0000                   0.0
# 2023-07-30               -1.0000                   0.0
# 2023-07-31                0.0000                   0.0
# 2023-08-01                0.0000                   0.0
#
#             rolling_3_snow_depth_pct  rolling_3_temp_max  ...  \
# DATE                                                      ...
# 2009-01-06                 -0.066667           17.000000  ...
# 2009-01-07                 -0.034483           17.000000  ...
# 2009-01-08                  0.000000           17.000000  ...
# 2009-01-09                  0.000000           23.333333  ...
# 2009-01-10                  0.000000           30.666667  ...
# ...                              ...                 ...  ...
# 2023-07-28                  0.000000           66.000000  ...
# 2023-07-29                  0.000000           66.666667  ...
# 2023-07-30                  0.000000           75.000000  ...
# 2023-07-31                  0.000000           83.333333  ...
# 2023-08-01                  0.000000           84.333333  ...
#
#             rolling_14_temp_min  rolling_14_temp_min_pct  month_avg_precip  \
# DATE
# 2009-01-06             1.500000                 0.333333          0.000000
# 2009-01-07             2.000000                 0.000000          0.000000
# 2009-01-08             2.000000                 0.000000          0.006667
# 2009-01-09             2.000000                 0.000000          0.010000
# 2009-01-10             3.500000                 5.571429          0.008000
# ...                         ...                      ...               ...
# 2023-07-28            51.928571                -0.056396          0.074073
# 2023-07-29            51.642857                -0.031812          0.073904
# 2023-07-30            51.428571                -0.008333          0.073736
# 2023-07-31            51.571429                 0.008310          0.073568
# 2023-08-01            52.071429                 0.037037          0.065891
#
#             day_avg_precip  month_avg_snow_depth  day_avg_snow_depth  \
# DATE
# 2009-01-06        0.000000                   2.8                 2.8
# 2009-01-07        0.000000                   2.8                 2.8
# 2009-01-08        0.020000                   2.8                 2.8
# 2009-01-09        0.020000                   2.8                 2.8
# 2009-01-10        0.000000                   2.8                 2.8
# ...                    ...                   ...                 ...
# 2023-07-28        0.019286                   0.0                 0.0
# 2023-07-29        0.022143                   0.0                 0.0
# 2023-07-30        0.022857                   0.0                 0.0
# 2023-07-31        0.000714                   0.0                 0.0
# 2023-08-01        0.060714                   0.0                 0.0
#
#             month_avg_temp_max  day_avg_temp_max  month_avg_temp_min  \
# DATE
# 2009-01-06           17.000000         17.000000            2.000000
# 2009-01-07           17.000000         17.000000            2.000000
# 2009-01-08           17.000000         17.000000            2.000000
# 2009-01-09           21.750000         36.000000            2.000000
# 2009-01-10           25.200000         39.000000            6.200000
# ...                        ...               ...                 ...
# 2023-07-28           74.791762         75.642857           51.160183
# 2023-07-29           74.796804         77.714286           51.157534
# 2023-07-30           74.831435         81.000000           51.157175
# 2023-07-31           74.850000         80.785714           51.159091
# 2023-08-01           74.277910         78.928571           49.572447
#
#             day_avg_temp_min
# DATE
# 2009-01-06          2.000000
# 2009-01-07          2.000000
# 2009-01-08          2.000000
# 2009-01-09          2.000000
# 2009-01-10         23.000000
# ...                      ...
# 2023-07-28         50.714286
# 2023-07-29         51.642857
# 2023-07-30         50.928571
# 2023-07-31         51.928571
# 2023-08-01         54.428571
#
# [5246 rows x 29 columns]

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 11.749566694985752

# %%
r2_ridge = r2_score(predictions["actual"], predictions["prediction"])
r2_ridge
# Out:
# -1.2433649937356575

# %%
rmse_ridge = mean_squared_error(predictions["actual"], predictions["prediction"], squared=False)
rmse_ridge
# Out:
# 14.160400714514923

# %%
predictions["diff"].mean()
# Out:
# 11.749566694985752

# %%
ridge_model.coef_
# Out:
# array([ 3.19847294e+00,  1.11871190e-01,  2.18158971e+00, -4.80179144e-01,
#         2.02801495e+00, -4.06631589e-01, -6.20692448e-01,  1.46183138e+00,
#        -1.86499561e-01,  1.33580148e-01, -4.95741101e-02, -5.39940916e-02,
#         1.78732255e+01, -4.40014197e-02, -7.23760216e-01, -3.85435266e-01,
#        -5.17181074e-02,  4.77699631e+00,  2.76076699e-01, -1.11626181e-02,
#         4.53905548e+00,  3.19847294e+00,  3.77918493e-01,  7.62564672e-02,
#        -4.43588997e-02, -1.74583870e+00,  2.32590997e-01,  7.66746027e-01])

# %%
predictions.sort_values("diff", ascending= False) # to sshow days with errors
# Out:
#             actual  prediction       diff
# DATE
# 2010-01-31    13.0  -21.153400  34.153400
# 2010-01-22    16.0   -9.525885  25.525885
# 2010-02-02    16.0   -6.184294  22.184294
# 2010-02-03     9.0  -12.063583  21.063583
# 2010-01-08    19.0   38.976175  19.976175
# 2010-01-21    15.0   -3.403252  18.403252
# 2010-01-30     9.0   -9.287375  18.287375
# 2010-01-19    19.0    1.648584  17.351416
# 2010-02-06    10.0   -5.954378  15.954378
# 2010-01-24     5.0   19.208152  14.208152
# 2010-02-04     5.0   -8.999081  13.999081
# 2010-01-12    29.0   16.256757  12.743243
# 2010-01-17    21.0    8.583790  12.416210
# 2010-01-09    31.0   18.883111  12.116889
# 2010-01-23    11.0   22.946504  11.946504
# 2010-01-13    25.0   13.293657  11.706343
# 2010-01-29    13.0    2.246860  10.753140
# 2010-02-05     1.0   -8.574594   9.574594
# 2010-01-28     9.0   16.452601   7.452601
# 2010-01-20    17.0   10.021967   6.978033
# 2010-01-14    22.0   28.713786   6.713786
# 2010-01-25    -2.0   -8.685013   6.685013
# 2010-01-11    33.0   27.430498   5.569502
# 2010-02-01    13.0   17.908195   4.908195
# 2010-01-27     3.0   -1.135449   4.135449
# 2010-01-26    -6.0   -2.231949   3.768051
# 2010-01-18    17.0   15.229906   1.770094
# 2010-01-15    22.0   20.700459   1.299541
# 2010-01-10    29.0   28.450066   0.549934
# 2010-01-16    12.0   11.707113   0.292887

# %%
Calgary1cfs_df.loc["2010-01-25":"2010-02-01"]
# Out:
#             precip  snow_depth  temp_max  temp_min  target  rolling_3_precip  \
# DATE
# 2010-01-25     0.0         0.8      11.0       5.0    -2.0               0.0
# 2010-01-26     0.0         1.6      15.0      -2.0    -6.0               0.0
# 2010-01-27     0.0         1.2      22.0      -6.0     3.0               0.0
# 2010-01-28     0.0         1.2      32.0       3.0     9.0               0.0
# 2010-01-29     0.0         1.6      30.0       9.0    13.0               0.0
# 2010-01-30     0.0         1.6      20.0      13.0     9.0               0.0
# 2010-01-31     0.0         2.4      14.0       9.0    13.0               0.0
# 2010-02-01     0.0         2.8      36.0      13.0    13.0               0.0
#
#             rolling_3_precip_pct  rolling_3_snow_depth  \
# DATE
# 2010-01-25                   0.0              0.933333
# 2010-01-26                   0.0              1.200000
# 2010-01-27                   0.0              1.200000
# 2010-01-28                   0.0              1.333333
# 2010-01-29                   0.0              1.333333
# 2010-01-30                   0.0              1.466667
# 2010-01-31                   0.0              1.866667
# 2010-02-01                   0.0              2.266667
#
#             rolling_3_snow_depth_pct  rolling_3_temp_max  ...  \
# DATE                                                      ...
# 2010-01-25             -1.428571e-01           16.000000  ...
# 2010-01-26              3.333333e-01           14.666667  ...
# 2010-01-27             -5.551115e-16           16.000000  ...
# 2010-01-28             -1.000000e-01           23.000000  ...
# 2010-01-29              2.000000e-01           28.000000  ...
# 2010-01-30              9.090909e-02           27.333333  ...
# 2010-01-31              2.857143e-01           21.333333  ...
# 2010-02-01              2.352941e-01           23.333333  ...
#
#             rolling_14_temp_min  rolling_14_temp_min_pct  month_avg_precip  \
# DATE
# 2010-01-25            18.857143                -0.734848          0.002353
# 2010-01-26            16.357143                -1.122271          0.002308
# 2010-01-27            13.857143                -1.432990          0.002264
# 2010-01-28            12.285714                -0.755814          0.002222
# 2010-01-29            11.357143                -0.207547          0.002182
# 2010-01-30            10.714286                 0.213333          0.002143
# 2010-01-31            10.500000                -0.142857          0.002105
# 2010-02-01             9.928571                 0.309353          0.005172
#
#             day_avg_precip  month_avg_snow_depth  day_avg_snow_depth  \
# DATE
# 2010-01-25             0.0              1.662745                 1.0
# 2010-01-26             0.0              1.661538                 1.4
# 2010-01-27             0.0              1.652830                 1.2
# 2010-01-28             0.0              1.644444                 1.0
# 2010-01-29             0.0              1.643636                 1.2
# 2010-01-30             0.0              1.642857                 1.0
# 2010-01-31             0.0              1.656140                 1.2
# 2010-02-01             0.0              1.586207                 1.8
#
#             month_avg_temp_max  day_avg_temp_max  month_avg_temp_min  \
# DATE
# 2010-01-25           32.901961              13.0           11.960784
# 2010-01-26           32.557692              16.0           11.692308
# 2010-01-27           32.358491              29.0           11.358491
# 2010-01-28           32.351852              33.5           11.203704
# 2010-01-29           32.309091              37.5           11.163636
# 2010-01-30           32.089286              34.5           11.196429
# 2010-01-31           31.771930              29.0           11.157895
# 2010-02-01           29.172414              35.0            9.551724
#
#             day_avg_temp_min
# DATE
# 2010-01-25              -5.0
# 2010-01-26              -6.5
# 2010-01-27               2.0
# 2010-01-28              12.0
# 2010-01-29              14.0
# 2010-01-30              25.5
# 2010-01-31              12.0
# 2010-02-01              12.0
#
# [8 rows x 29 columns]

# %%
predictions["diff"].round().value_counts().sort_index()
# Out:
# diff
# 0.0     1
# 1.0     2
# 2.0     1
# 4.0     2
# 5.0     1
# 6.0     1
# 7.0     4
# 10.0    1
# 11.0    1
# 12.0    4
# 13.0    1
# 14.0    2
# 16.0    1
# 17.0    1
# 18.0    2
# 20.0    1
# 21.0    1
# 22.0    1
# 26.0    1
# 34.0    1
# Name: count, dtype: int64

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>

# %% [markdown]
# conclusion to improve the model, we always create more columns , add to the predictors and run it.

# %% [markdown]
# little variations occured as we can see.

# %%
ridge_model.coef_
# Out:
# array([ 3.19847294e+00,  1.11871190e-01,  2.18158971e+00, -4.80179144e-01,
#         2.02801495e+00, -4.06631589e-01, -6.20692448e-01,  1.46183138e+00,
#        -1.86499561e-01,  1.33580148e-01, -4.95741101e-02, -5.39940916e-02,
#         1.78732255e+01, -4.40014197e-02, -7.23760216e-01, -3.85435266e-01,
#        -5.17181074e-02,  4.77699631e+00,  2.76076699e-01, -1.11626181e-02,
#         4.53905548e+00,  3.19847294e+00,  3.77918493e-01,  7.62564672e-02,
#        -4.43588997e-02, -1.74583870e+00,  2.32590997e-01,  7.66746027e-01])

# %% [markdown]
# These coefficients represent the estimated impact of each predictor on the target variable (temp_min)
# Precipitation (precip): 9.52623501 This indicate a positive coefficient indicates that an increase in precipitation is associated with an increase in the temp_min.
# Analysis: This suggests that higher levels of precipitation are correlated with higher minimum temperatures. This might be due to the fact that rainy or wet conditions can lead to a warming effect, preventing temperatures from dropping as low.
# Snow Depth (snow_depth): -0.80945195 :a negative coefficient indicates that an increase in snow depth is associated with a decrease in the temp_min.
# Analysis: This suggests an inverse relationship between snow depth and minimum temperature. As snow accumulates, it tends to have a cooling effect on the surrounding environment, resulting in lower minimum temperatures.
# Maximum Temperature (temp_max): 0.75077928 a positive coefficient indicates that an increase in maximum temperature is associated with an increase in the temp_min.
# Analysis: This suggests that higher maximum temperatures are correlated with higher minimum temperatures. Warmer days might lead to milder nights, resulting in higher minimum temperatures.

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create an SVR model
svr_model = SVR(kernel='linear')  # You can choose different kernel functions

# Fit the model on the training data
svr_model.fit(X_train, y_train)

# Make predictions
y_pred = svr_model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Support Vector Regression Metrics:")
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Support Vector Regression Metrics:
# Mean Squared Error: 68.01303615132274
# Mean Absolute Error: 6.641073449531379
# R-squared: 0.8523454251855682
